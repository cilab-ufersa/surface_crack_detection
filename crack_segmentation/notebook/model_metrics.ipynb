# %% [markdown]
# ### **1. Importing necessary package**

# %%
import pandas as pd

# %% [markdown]
# ### **2. Loading the metrics of models**

# %%
paths = ['output/crack_detection_1.out', 'output/crack_detection_2.out']
unet_mobilenet = pd.read_csv(paths[0], delimiter=';')
fpn_inceptionv3 = pd.read_csv(paths[1], delimiter=';')

# %% [markdown]
# ### **3. Showing up the results**

# %% [markdown]
# #### 3.1. Unet-mobilenet

# %%
unet_mobilenet
# Out:
#     epoch  F1_score  F1_score_dil  Precision  Precision_dil    Recall  \
# 0       0  0.489353      0.584747   0.376110       0.479062  0.876841
# 1       1  0.609178      0.723942   0.486828       0.626533  0.921282
# 2       2  0.670446      0.795904   0.548970       0.714188  0.936980
# 3       3  0.703719      0.834381   0.580426       0.758759  0.952371
# 4       4  0.677078      0.803742   0.550428       0.717034  0.944861
# ..    ...       ...           ...        ...            ...       ...
# 95     95  0.789056      0.928643   0.672822       0.882544  0.986854
# 96     96  0.779969      0.914291   0.663594       0.863163  0.982290
# 97     97  0.801255      0.937804   0.689112       0.898149  0.986578
# 98     98  0.807659      0.942650   0.697987       0.908418  0.986183
# 99     99  0.805108      0.938273   0.694482       0.899883  0.985960
#
#     accuracy       loss  val_F1_score  val_F1_score_dil  val_Precision  \
# ...

# %%
precision = unet_mobilenet.iloc[99, 3]
recall = unet_mobilenet.iloc[99, 5]
f1_score = unet_mobilenet.iloc[99, 1]

print(f"Precision: {(precision * 100):.2f}%")
print(f"Recall: {(recall * 100):.2f}%")
print(f"F1_score: {(f1_score * 100):.2f}%")
# Out:
# Precision: 69.45%
# Recall: 98.60%
# F1_score: 80.51%

# %% [markdown]
# #### 3.2. FPN-inceptionv3

# %%
fpn_inceptionv3
# Out:
#     epoch  F1_score  F1_score_dil  Precision  Precision_dil    Recall  \
# 0       0  0.447752      0.552171   0.331719       0.439413  0.871955
# 1       1  0.622146      0.756055   0.490273       0.653779  0.938261
# 2       2  0.662162      0.800811   0.533560       0.713246  0.950168
# 3       3  0.654542      0.793353   0.519480       0.693555  0.958913
# 4       4  0.700013      0.837260   0.569987       0.754311  0.966032
# ..    ...       ...           ...        ...            ...       ...
# 95     95  0.752696      0.892745   0.627960       0.829201  0.980017
# 96     96  0.782358      0.921396   0.663307       0.872985  0.983128
# 97     97  0.781804      0.921276   0.663769       0.873368  0.982900
# 98     98  0.785723      0.923774   0.669158       0.878362  0.982859
# 99     99  0.790554      0.930558   0.672749       0.887107  0.983709
#
#     accuracy       loss  val_F1_score  val_F1_score_dil  val_Precision  \
# ...

# %%
precision = fpn_inceptionv3.iloc[99, 3]
recall = fpn_inceptionv3.iloc[99, 5]
f1_score = fpn_inceptionv3.iloc[99, 1]

print(f"Precision: {(precision * 100):.2f}%")
print(f"Recall: {(recall * 100):.2f}%")
print(f"F1_score: {(f1_score * 100):.2f}%")
# Out:
# Precision: 67.27%
# Recall: 98.37%
# F1_score: 79.06%
