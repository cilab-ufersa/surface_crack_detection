# %% [markdown]
# ### **Importing necessary package**

# %%
import pandas as pd

# %% [markdown]
# ### **Loading the metrics of models**

# %%
paths = ['output/crack_detection_1.out', 'output/crack_detection_2.out']
unet_mobilenet = pd.read_csv(paths[0], delimiter=';')
fpn_inceptionv3 = pd.read_csv(paths[1], delimiter=';', header=None)

# %% [markdown]
# ### **Showing up the results**

# %% [markdown]
# #### Unet-mobilenet

# %%
unet_mobilenet
# Out:
#         0                   1                   2                    3   \
# 0    epoch            F1_score        F1_score_dil            Precision
# 1        0  0.4893527626991272  0.5847465991973877   0.3761098086833954
# 2        1   0.609177827835083  0.7239418029785156  0.48682838678359985
# 3        2  0.6704462170600891  0.7959039211273193   0.5489695072174072
# 4        3  0.7037187814712524  0.8343808650970459   0.5804264545440674
# ..     ...                 ...                 ...                  ...
# 96      95  0.7890564203262329  0.9286434650421143   0.6728221774101257
# 97      96  0.7799693942070007   0.914290726184845   0.6635939478874207
# 98      97    0.80125492811203  0.9378035664558411   0.6891119480133057
# 99      98   0.807659387588501  0.9426503777503967   0.6979873180389404
# 100     99   0.805107831954956  0.9382733106613159   0.6944820880889893
#
#                       4                   5                   6   \
# ...

# %%
print("F1_score: {}".format(unet_mobilenet.iloc[99, 1]))
print("Precision: {}".format(unet_mobilenet.iloc[99, 3]))
print("Recall: {}".format(unet_mobilenet.iloc[99, 5]))
# Out:
# F1_score: 0.807659387588501
# Precision: 0.6979873180389404
# Recall: 0.9861829280853271

# %% [markdown]
# #### FPN-inceptionv3

# %%
fpn_inceptionv3
# Out:
#         0                    1                   2                    3   \
# 0    epoch             F1_score        F1_score_dil            Precision
# 1        0  0.44775158166885376  0.5521714687347412  0.33171889185905457
# 2        1   0.6221463680267334  0.7560551762580872   0.4902729392051697
# 3        2   0.6621619462966919  0.8008105754852295   0.5335597395896912
# 4        3    0.654542088508606  0.7933526039123535   0.5194798707962036
# ..     ...                  ...                 ...                  ...
# 96      95   0.7526964545249939  0.8927447199821472   0.6279599666595459
# 97      96   0.7823583483695984  0.9213964939117432   0.6633068323135376
# 98      97   0.7818044424057007  0.9212759733200073    0.663769006729126
# 99      98   0.7857229709625244  0.9237738847732544    0.669157862663269
# 100     99   0.7905540466308594   0.930558443069458   0.6727493405342102
#
#                       4                   5                   6   \
# ...

# %%
print("F1_score: {}".format(fpn_inceptionv3.iloc[99, 1]))
print("Precision: {}".format(fpn_inceptionv3.iloc[99, 3]))
print("Recall: {}".format(fpn_inceptionv3.iloc[99, 5]))
# Out:
# F1_score: 0.7857229709625244
# Precision: 0.669157862663269
# Recall: 0.982859194278717
