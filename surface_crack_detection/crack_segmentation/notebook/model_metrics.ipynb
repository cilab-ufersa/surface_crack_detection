# %% [markdown]
# ### **1. Importing necessary package**

# %%
import pandas as pd

# %% [markdown]
# ### **2. Loading the models' metrics**

# %%
paths = ['../output/crack_detection_6.out', "../output/crack_detection_2.out"]

unet_mobilenet = pd.read_csv(paths[0], delimiter=';')
fpn_inceptionv3 = pd.read_csv(paths[1], delimiter=';')

# %% [markdown]
# ### **3. Showing up the results**

# %% [markdown]
# #### 3.1. Unet-mobilenet

# %%
unet_mobilenet
# Out:
#     epoch  F1_score  F1_score_dil  Precision  Precision_dil    Recall  \
# 0       0  0.458440      0.562313   0.328770       0.434824  0.901494
# 1       1  0.714969      0.846484   0.590689       0.773663  0.953857
# 2       2  0.789215      0.913854   0.679798       0.870810  0.968668
# 3       3  0.813680      0.929434   0.710581       0.895796  0.969992
# 4       4  0.822838      0.938436   0.721091       0.907220  0.975188
# 5       5  0.836064      0.948257   0.738694       0.924087  0.976385
# 6       6  0.849637      0.958754   0.756980       0.941731  0.977503
# 7       7  0.853343      0.961635   0.760462       0.944613  0.980405
# 8       8  0.836996      0.949008   0.737667       0.922088  0.979514
# 9       9  0.848294      0.957255   0.754353       0.937544  0.979764
# 10     10  0.847373      0.956265   0.752348       0.934877  0.980397
# 11     11  0.856108      0.964595   0.761886       0.944895  0.986651
# ...

# %%
precision = unet_mobilenet['Precision'].mean()
recall = unet_mobilenet['Recall'].mean()
f1_score = unet_mobilenet['F1_score'].mean()
accuracy = unet_mobilenet['accuracy'].mean()
val_accuracy = unet_mobilenet['val_accuracy'].mean()
loss = unet_mobilenet['loss'].mean()
val_loss = unet_mobilenet['val_loss'].mean()

print("====== unet's metrics ======")
print(f"Precision: {(precision * 100):.2f}%")
print(f"Recall: {(recall * 100):.2f}%")
print(f"F1_score: {(f1_score * 100):.2f}%")
print(f"accuracy: {(accuracy * 100):.2f}%")
print(f"val_accuracy: {(val_accuracy * 100):.2f}%")
print(f"loss: {(loss):.2f}")
print(f"val_loss: {(val_loss):.2f}")
# Out:
# ====== unet's metrics ======
# Precision: 73.51%
# Recall: 98.03%
# F1_score: 83.31%
# accuracy: 98.43%
# val_accuracy: 96.00%
# loss: 4.58
# val_loss: 4.86

# %% [markdown]
# #### 3.2. FPN-inceptionv3

# %%
fpn_inceptionv3
# Out:
#     epoch  F1_score  F1_score_dil  Precision  Precision_dil    Recall  \
# 0       0  0.447752      0.552171   0.331719       0.439413  0.871955
# 1       1  0.622146      0.756055   0.490273       0.653779  0.938261
# 2       2  0.662162      0.800811   0.533560       0.713246  0.950168
# 3       3  0.654542      0.793353   0.519480       0.693555  0.958913
# 4       4  0.700013      0.837260   0.569987       0.754311  0.966032
# ..    ...       ...           ...        ...            ...       ...
# 95     95  0.752696      0.892745   0.627960       0.829201  0.980017
# 96     96  0.782358      0.921396   0.663307       0.872985  0.983128
# 97     97  0.781804      0.921276   0.663769       0.873368  0.982900
# 98     98  0.785723      0.923774   0.669158       0.878362  0.982859
# 99     99  0.790554      0.930558   0.672749       0.887107  0.983709
#
#     accuracy       loss  val_F1_score  val_F1_score_dil  val_Precision  \
# ...

# %%
precision = fpn_inceptionv3['Precision'].mean()
recall = fpn_inceptionv3['Recall'].mean()
f1_score = fpn_inceptionv3['F1_score'].mean()
accuracy = fpn_inceptionv3['accuracy'].mean()
val_accuracy = fpn_inceptionv3['val_accuracy'].mean()
loss = fpn_inceptionv3['loss'].mean()
val_loss = fpn_inceptionv3['val_loss'].mean()

print("====== FPN's metrics ======")
print(f"Precision: {(precision * 100):.2f}%")
print(f"Recall: {(recall * 100):.2f}%")
print(f"F1_score: {(f1_score * 100):.2f}%")
print(f"accuracy: {(accuracy * 100):.2f}%")
print(f"val_accuracy: {(val_accuracy * 100):.2f}%")
print(f"loss: {(loss):.2f}")
print(f"val_loss: {(val_loss):.2f}")
# Out:
# ====== FPN's metrics ======
# Precision: 59.31%
# Recall: 96.90%
# F1_score: 71.90%
# accuracy: 97.07%
# val_accuracy: 92.70%
# loss: 2.59
# val_loss: 4.11
